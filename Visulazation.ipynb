# %%
#importing necessary Libraries
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import matplotlib.pyplot as mp
import numpy as np

from datetime import datetime as dt, timedelta

# %% [markdown]
# #Data Uploading

# %%
xls = pd.ExcelFile(r'C:\Users\Rishabh\Downloads\RAW Crypto exchanges May 2022.xlsx')
df1 = pd.read_excel(xls, 'Total traffic')
df2 = pd.read_excel(xls, 'Total traffic % change')
df3 = pd.read_excel(xls, 'Unique visitors')
df4 = pd.read_excel(xls, 'Unique visits % change')
df5 = pd.read_excel(xls, '% of unique visitors')
df6 = pd.read_excel(xls, ' % of unique visitors change')
df7 = pd.read_excel(xls, 'Pagesvisit')
df8 = pd.read_excel(xls, 'Visit Duration')
df9 = pd.read_excel(xls, 'Bulk Analysis (date=Apr 2022)')

# %%
df1 = df1.iloc[1:]

# %%
df1new = df1.fillna(0)
df1new.columns = df1new.columns[0:1].to_list() +  pd.to_datetime(df1new.columns[1:15]).strftime('%b-%Y').to_list() + df1new.columns[15:].to_list()
df1new.head(5)
# Out:
#          Target   Mar-2021   Apr-2021   May-2021   Jun-2021   Jul-2021  \
# 1   bexplus.com     267985     967108     237398     902521     698423
# 2   binance.com  106627301  241221218  334676452  168527410  160118899
# 3     bingx.com          0          0          0          0          0
# 4  bisq.network     116870     110337     334988      95360      26956
# 5     bitbuy.ca     456981     918193     484990     194208     134880
#
#     Aug-2021   Sep-2021   Oct-2021   Nov-2021   Dec-2021   Jan-2022  \
# 1    3072953     889200     858420     131045     617376     318207
# 2  189334310  164895777  193038325  207239832  160335689  152148105
# 3          0          0          0      79341    5184493     711746
# 4      42384       3924        170       4191       4035      20510
# 5     477768     247877     656050     550110     293407     369894
#
#     Feb-2022   Mar-2022   Apr-2022         Total
# 1     148923    1146609     657536  1.091370e+07
# ...

# %% [markdown]
# # Plot For Monthly Total Traffic

# %%
df1new.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))
df1new.plot(x="Target", y=["Total"], kind="bar", figsize=(14, 6))
mp.show()

# %%
df2 = df2.iloc[1:]

# %%
df2.columns = df2.columns[0:1].to_list() +  pd.to_datetime(df2.columns[1:15]).strftime('%b-%Y').to_list() + df2.columns[15:].to_list()

# %%
df2new = df2.replace('#VALUE!', np.NaN)

# %%
df2new1 = df2new.fillna(0)

# %% [markdown]
# # Plot for Monthly Total traffic % change

# %%
df2new1.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df2new1.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))
mp.show()

# %%
df3 = df3.iloc[1:]

# %%
df3new = df3.fillna(0)
df3new.columns = df3new.columns[0:1].to_list() +  pd.to_datetime(df3new.columns[1:15]).strftime('%b-%Y').to_list() + df3new.columns[15:].to_list()

# %% [markdown]
# # Plot for Monthly Unique visitors

# %%
df3new.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))
df3new.plot(x="Target", y=["total"], kind="bar", figsize=(14, 6))

mp.show()

# %%
df4 = df4.iloc[1:]

# %%
df4.columns = df4.columns[0:1].to_list() +  pd.to_datetime(df4.columns[1:15]).strftime('%b-%Y').to_list() + df4.columns[15:].to_list()

# %%
df4new = df4.replace('#VALUE!', np.NaN)

# %%
df4new1 = df4new.fillna(0)

# %% [markdown]
# # Plot For Monthly Unique visit Percent Change

# %%
df4new1.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df4new1.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))

mp.show()

# %%
df5 = df5.iloc[1:]

# %%
df5.columns = df5.columns[0:1].to_list() +  pd.to_datetime(df5.columns[1:15]).strftime('%b-%Y').to_list() + df5.columns[15:].to_list()

# %%
df5new = df5.replace('#VALUE!', np.NaN)

# %%
df5new1 = df5new.fillna(0)

# %% [markdown]
# # Plot For  monthly Percent of Unique Visitors

# %%
df5new1.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))
df5new1.plot(x="Target", y=["Unnamed: 15"], kind="bar", figsize=(14, 6))


mp.show()

# %%
df6 = df6.iloc[1:]

# %%
df6.columns = df6.columns[0:1].to_list() +  pd.to_datetime(df6.columns[1:15]).strftime('%b-%Y').to_list() + df6.columns[15:].to_list()

# %%
df6new = df6.replace('#VALUE!', np.NaN)

# %%
df6new1 = df6new.fillna(0)

# %% [markdown]
# # Plot For monthly Percent of unique visitors change

# %%
df6new1.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df6new1.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))



mp.show()

# %%
df7 = df7.iloc[1:]

# %%
df7new = df7.fillna(0)
df7new.columns = df7new.columns[0:1].to_list() +  pd.to_datetime(df7new.columns[1:15]).strftime('%b-%Y').to_list() + df7new.columns[15:].to_list()

# %% [markdown]
# # Plot For Monthly Pages Visit

# %%
df7new.plot(x="Target", y=["Mar-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Apr-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Jun-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Jul-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Aug-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Sep-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Oct-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Nov-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Dec-2021"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Jan-2022"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Feb-2022"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Mar-2022"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["Apr-2022"], kind="bar", figsize=(14, 6))
df7new.plot(x="Target", y=["total"], kind="bar", figsize=(14, 6))

mp.show()

# %%
df8 = df8.iloc[1:]

# %%
#Still need more time  data manipulation for visualization of Visit Duration because data is not in well format
df8
# Out:
#             Target  2021-03-01 00:00:00  2021-04-01 00:00:00  \
# 1      bexplus.com             01:15:00             04:20:00
# 2      binance.com  1900-01-01 04:01:00             23:41:00
# 3        bingx.com                  NaN                  NaN
# 4     bisq.network             03:42:00             05:37:00
# 5        bitbuy.ca  1900-01-01 00:31:00  1900-01-01 02:37:00
# 6   bitcoinira.com             06:00:00             12:14:00
# 7     bitfinex.com             20:21:00             20:01:00
# 8     bitflyer.com             14:51:00             14:26:00
# 9      bithumb.com  1900-01-01 08:06:00             13:42:00
# 10     bitmart.com             09:53:00  1900-01-01 20:16:00
# 11      bitmex.com  1900-01-01 06:01:00             20:02:00
# 12    bitpanda.com             16:45:00             17:31:00
# 13   lbitstamp.net                  NaN                  NaN
# 14     bittrex.com             19:41:00             22:38:00
# ...

# %% [markdown]
# # Co-relation Plot For Bulk Analysis Showing Corelation between different Entities

# %%
dataplot = sb.heatmap(df9.corr(), cmap="YlGnBu", annot=True)

# %%
#This work is basically involves basic data visalization it need more time for specific analysis
